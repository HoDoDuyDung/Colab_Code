# %% [markdown]
# <a href="https://colab.research.google.com/github/HoDoDuyDung/Colab_Code/blob/main/HoDoDuyDung_20146235_Shampoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 bien bac 3
import pandas as pd
url = 'passenger.csv'
data = pd.read_csv(url)
data.head()

import matplotlib.pyplot as plt
data.hist()
plt.show()
correlation = data.corr()
print(correlation)

import seaborn as sns
sns.heatmap(correlation,annot=True)
sns.pairplot(data)

from sklearn import linear_model
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Miles(X)'],data['Miles(X)']**2,data['Miles(X)']**3]).T
model.fit(X,y=data['Dollars (Y)'])
print('Intercept cua mo hinh :', model.intercept_)
print('Coeffient cua mo hinh :', model.coef_)
print('Do chinh xac cua mo hinh :', model.score(X = pd.DataFrame([data['Miles(X)'],data['Miles(X)']**2,data['Miles(X)']**3]).T, y=data['Dollars (Y)']))

import numpy as np
range = np.arange(0,175000,1000) 
X_range = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X=X_range)
data.plot(kind = 'scatter', x = 'Miles(X)',y='Dollars (Y)',figsize=(9,9),color = 'black')
plt.plot(range,y_pred,color='blue')
# Out:
#              Passenger  Miles(X)  Dollars (Y)
# Passenger     1.000000 -0.067441     0.050511
# Miles(X)     -0.067441  1.000000     0.921729
# Dollars (Y)   0.050511  0.921729     1.000000
# Intercept cua mo hinh : 4060.482845976633
# Coeffient cua mo hinh : [-2.77719956e+00  1.26814625e-03 -1.22050424e-07]
# Do chinh xac cua mo hinh : 0.9623891949969419
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 1 bien bac 1
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['Miles(X)']), y=data['Dollars (Y)'])
print('He so intercept la :', model.intercept_)
print('He so coeffient :', model.coef_)

model.score(X=pd.DataFrame(data['Miles(X)']), y=data['Dollars (Y)'])

y_pred = model.predict(X=pd.DataFrame(data['Miles(X)']))

data.plot(kind = 'scatter', x = 'Miles(X)', y = 'Dollars (Y)', figsize=(9,9), color = 'black')
plt.plot(data['Miles(X)'],y_pred,color='blue')
# Out:
# He so intercept la : 934.5366384552517
# He so coeffient : [1.07802533]
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 3 bien bac 1
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['Miles(X)','Passenger']],y = data['Dollars (Y)'])
print('Intercept cua mo hinh :', model.intercept_)
print('Coeffient cua mo hinh :', model.coef_)
print('Do chinh xac cua mo hinh :', model.score(X=data.loc[:,['Miles(X)','Passenger']],y = data['Dollars (Y)']))
# Out:
# Intercept cua mo hinh : 573.3809447573494
# Coeffient cua mo hinh : [ 1.0869533  25.65975717]
# Do chinh xac cua mo hinh : 0.8623380550442818
